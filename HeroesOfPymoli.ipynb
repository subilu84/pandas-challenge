# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
total = purchase_data["SN"].nunique()
total
# Out:
# 576

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
total_df = pd.DataFrame ([{
    "Total Players" : total
}])
total_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
num_item =purchase_data["Item ID"].nunique()
num_item
# Out:
# 183

# %%
avg_p = purchase_data["Price"].mean()
avg_p
# Out:
# 3.050987179487176

# %%
num_pur = purchase_data["Purchase ID"].count()
num_pur
# Out:
# 780

# %%
total_p = purchase_data["Price"].sum()
total_p
# Out:
# 2379.77

# %%
#Display the summary in a data frame
result_df = pd.DataFrame([{
    "Number of Unique Items": num_item,
    "Average Price": avg_p,
    "Number of Purchases": num_pur,
    "Total Revenue": total_p
}])
result_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     183       3.050987                  780        2379.77

# %%
#Format the numbers
result_df["Average Price"] = result_df["Average Price"].map("${:.2f}".format)
result_df["Total Revenue"] = result_df["Total Revenue"].map("${:.2f}".format)
#result_df["Total Revenue"] = result_df["Total Revenue"].map("${:,f}".format)
result_df
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     183         $3.05                  780      $2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#Create a new df called data
data = purchase_data
data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
#Saved it so I can clean it
data.to_csv("data.csv", index=False)
data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
# Clean the row SN now I don't have any duplicate at row Gender
data.drop_duplicates(subset = "SN",keep = 'first', inplace = True)
data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 774          774     Jiskjask80   11    Male      101
# 775          775     Aethedru70   21  Female       60
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
gender_df = data[["SN", "Gender","Age"]]
gender_df
# Out:
#                 SN  Gender
# 0          Lisim78    Male
# 1      Lisovynya38    Male
# 2       Ithergue48    Male
# 3    Chamassasya86    Male
# 4        Iskosia90    Male
# ..             ...     ...
# 773         Hala31    Male
# 774     Jiskjask80    Male
# 775     Aethedru70  Female
# 777     Yathecal72    Male
# 778        Sisur91    Male
#
# [576 rows x 2 columns]

# %%
total_g = gender_df["SN"].nunique()
total_g
# Out:
# 576

# %%
df = gender_df['Gender'].value_counts()
per_df =(df/total_g)*100

gender_data = pd.DataFrame({"Total Count":df, "percentage":per_df})
gender_data
# Out:
#                        Total Count  percentage
# Male                           484   84.027778
# Female                          81   14.062500
# Other / Non-Disclosed           11    1.909722

# %%
gender_data["percentage"] = gender_data["percentage"].map("${:.2f}".format)
gender_data
# Out:
#                        Total Count percentage
# Male                           484     $84.03
# Female                          81     $14.06
# Other / Non-Disclosed           11      $1.91

# %%
gen_df = pd.DataFrame((df/total_g)*100)

#rename the SN column
gen_df.rename(columns = {"SN":"Percentage of Players"}, inplace=True)

gen_df
# Out:
#                        Percentage of Players
# Gender
# Female                             14.062500
# Male                               84.027778
# Other / Non-Disclosed               1.909722

# %%
finalg_df = pd.merge(df, gen_df, how = 'left', on =["Gender","Gender"])
finalg_df
# Out:
#                                              Total Count  \
# Gender                Gender
# Female                Female                          81
# Male                  Male                           484
# Other / Non-Disclosed Other / Non-Disclosed           11
#
#                                              Percentage of Players
# Gender                Gender
# Female                Female                             14.062500
# Male                  Male                               84.027778
# Other / Non-Disclosed Other / Non-Disclosed               1.909722

# %%
finalg_df["Percentage of Players"] = finalg_df["Percentage of Players"].map("${:.2f}".format)
finalg_df
# Out:
#                                              Total Count Percentage of Players
# Gender                Gender
# Female                Female                          81                $14.06
# Male                  Male                           484                $84.03
# Other / Non-Disclosed Other / Non-Disclosed           11                 $1.91

# %%
# Out:
#                        Total Count Percentage of Players
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
total_buy = purchase_data.groupby('Gender').count()["Price"]
total_avg = purchase_data.groupby('Gender').mean()["Price"]
total_sum = purchase_data.groupby('Gender').sum()["Price"]
total_person = total_sum / df 
p_analysis_df = pd.DataFrame({"Count":total_buy,
                              "Average Purchase": total_avg,
                              "Puchase sum": total_sum,
                               "Avg per person": total_person})
p_analysis_df
# Out:
#                        Count  Average Purchase  Puchase sum  Avg per person
# Gender
# Female                   113          3.203009       361.94        4.468395
# Male                     652          3.017853      1967.64        4.065372
# Other / Non-Disclosed     15          3.346000        50.19        4.562727

# %%
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
gender_df = data[["SN", "Gender","Age"]]
gender_df
# Out:
#                 SN  Gender  Age
# 0          Lisim78    Male   20
# 1      Lisovynya38    Male   40
# 2       Ithergue48    Male   24
# 3    Chamassasya86    Male   24
# 4        Iskosia90    Male   23
# ..             ...     ...  ...
# 773         Hala31    Male   21
# 774     Jiskjask80    Male   11
# 775     Aethedru70  Female   21
# 777     Yathecal72    Male   20
# 778        Sisur91    Male    7
#
# [576 rows x 3 columns]

# %%
bins = [0, 9, 15, 20, 25, 30, 35, 40, 101]

group_labels =["0 to 9","10 to 14", "15 to 19", "20 to 24", "25 to 29", "30 to 34", "35 to 39","40 to 101"]

# %%
print(bins)
print(group_labels)
# Out:
# [0, 9, 15, 20, 25, 30, 35, 40, 101]
# ['0 to 9', '10 to 14', '15 to 19', '20 to 24', '25 to 29', '30 to 34', '35 to 39', '40 to 101']

# %%
# Place the data series into a new column inside of the DataFrame
data["Total Age"] = pd.cut(data["Age"], bins, labels=group_labels)
data.head(3)
# Out:
#    Purchase ID           SN  Age Gender  Item ID  \
# 0            0      Lisim78   20   Male      108
# 1            1  Lisovynya38   40   Male      143
# 2            2   Ithergue48   24   Male       92
#
#                                    Item Name  Price Total Age
# 0  Extraction, Quickblade Of Trembling Hands   3.53  15 to 19
# 1                          Frenzied Scimitar   1.56  35 to 39
# 2                               Final Critic   4.88  20 to 24

# %%
total_age = data["Total Age"].value_counts()

percentage = total_age / 576

age_demo_df = pd.DataFrame({"Total Age" :total_age,
                            "Percentage":percentage
    
})

age_demo_df = age_demo_df.sort_index()
age_demo_df
# Out:
#            Total Age  Percentage
# 0 to 9            17    0.029514
# 10 to 14          48    0.083333
# 15 to 19         150    0.260417
# 20 to 24         232    0.402778
# 25 to 29          59    0.102431
# 30 to 34          37    0.064236
# 35 to 39          26    0.045139
# 40 to 101          7    0.012153

# %%
total_a = data["Age"].count()
total_a
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
bins = [0, 9, 15, 20, 25, 30, 35, 40, 101]

group_labels =["0 to 9","10 to 14", "15 to 19", "20 to 24", "25 to 29", "30 to 34", "35 to 39","40 to 101"]

# %%
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
purchase_data.head(3)
# Out:
#    Purchase ID           SN  Age Gender  Item ID  \
# 0            0      Lisim78   20   Male      108
# 1            1  Lisovynya38   40   Male      143
# 2            2   Ithergue48   24   Male       92
#
#                                    Item Name  Price Total Age
# 0  Extraction, Quickblade Of Trembling Hands   3.53  15 to 19
# 1                          Frenzied Scimitar   1.56  35 to 39
# 2                               Final Critic   4.88  20 to 24

# %%
summary_df = purchase_data

# %%
summary_df

# %%
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 108     Extraction, Quickblade Of Trembling Hands                 9
# 82      Nirvana                                                   9
# 19      Pursuit, Cudgel of Necromancy                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 92      Final Critic                                              8
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
